# %%
from pathlib import Path
import seaborn as sns
import pandas as pd
import os
import matplotlib.pyplot as plt
dir= '/standard/BDShackathon/data/leukemia/clinical'

# %% [markdown]
# ## Read in relevant data and put into a dictionary for easy access

# %%
relevant_data = ['CytogeneticAbnormalities',
                 'Diagnosis',
                 'Medications',
                 'Outcomes',
                 'PatientHistory',
                 'PatientMaster',
                 'Physical',
                 'StemCellTransplant',
                 'TumorMarker_',
                 'FlowPanel',
                 'VitalStatus',
                 'ClinicalMol']

# %%
relevant_files = []
for filename in os.listdir(dir):
    if filename.endswith(".csv") and any(substring in filename for substring in relevant_data):
        relevant_files.append(filename)
        
print(relevant_files)
# Out:
# ['20250317_UVA_TumorMarkerFlowPanel_V4.csv', '20250317_UVA_PhysicalAssessment_V4.csv', '20250317_UVA_TumorMarker_V4.csv', '20250317_UVA_CytogeneticAbnormalities_V4.csv', '20250317_UVA_Diagnosis_V4.csv', '20250317_UVA_VitalStatus_V4.csv', '20250317_UVA_ClinicalMolLinkage_V4.csv', '20250317_UVA_Medications_V4.csv', '20250317_UVA_PatientMaster_V4.csv', '20250317_UVA_PatientHistory_V4.csv', '20250317_UVA_StemCellTransplant_V4.csv', '20250317_UVA_Outcomes_V4.csv']

# %%
names =[]
for filename in relevant_files:
    name = filename.split('_')[2]
    names.append(name)
print(names)
# Out:
# ['TumorMarkerFlowPanel', 'PhysicalAssessment', 'TumorMarker', 'CytogeneticAbnormalities', 'Diagnosis', 'VitalStatus', 'ClinicalMolLinkage', 'Medications', 'PatientMaster', 'PatientHistory', 'StemCellTransplant', 'Outcomes']

# %%
dir = '/standard/BDShackathon/data/leukemia/clinical/'

df_dict = {}
for i in range(len(relevant_files)):
    path = dir + relevant_files[i]
    df_dict[names[i]] = pd.read_csv(path)

df_dict
# Out:
# {'TumorMarkerFlowPanel':      AvatarKey  TumorMarkerKey FlowPanelName FlowPanelResult
#  0      A006746          271432         CD117        Positive
#  1      A006746          271432          CD13        Positive
#  2      A006746          271432          CD33        Positive
#  3      A006746          271432          CD34        Positive
#  4      A006746          271432          CD45        Positive
#  ...        ...             ...           ...             ...
#  1804   A040113          271451          CD34        Positive
#  1805   A040113          271451           CD4        Negative
#  1806   A040113          271451           CD5        Negative
#  1807   A040113          271451        HLA-DR        Positive
#  1808   A040114          271454          CD14        Positive
#
#  [1809 rows x 4 columns],
#  'PhysicalAssessment':     AvatarKey AgeAtPhysicalExam           AgeAtPhysicalExamFlag  \
#  0     A028337            68.334  Age derived from complete date
#  1     A029220            71.244  Age derived from complete date
#  2     A030204            58.671  Age derived from complete date
#  3     A030214            68.200  Age derived from complete date
#  4     A030996            76.142  Age derived from complete date
#  ..        ...               ...                             ...
#  130   A049239            55.592  Age derived from complete date
#  131   A049245            29.353  Age derived from complete date
#  132   A049252            57.953  Age derived from complete date
#  133   A049236            78.293  Age derived from complete date
#  134   A049237            58.101  Age derived from complete date
#
#       YearOfPhysicalExam  BodyWeight              BodyHeight  \
#  0                  2019        90.0                  180.00
#  1                  2018       117.0                  179.00
#  2                  2019        69.0                  162.00
#  3                  2019        81.0                  187.00
#  4                  2019        60.0  Unknown/Not Applicable
#  ..                  ...         ...                     ...
#  130                2021       108.9                  160.00
#  131                2024        73.9                  165.10
#  132                2024        77.2                  181.40
#  133                2022        59.3                  167.60
#  134                2019        86.6                  177.80
#
#                          BMI
#  0    Unknown/Not Applicable
#  1    Unknown/Not Applicable
#  2    Unknown/Not Applicable
#  3                     23.00
#  4    Unknown/Not Applicable
#  ..                      ...
#  130                   42.50
#  131                   27.10
#  132                   23.50
#  133                   21.10
#  134                   27.40
#
#  [135 rows x 7 columns],
#  'TumorMarker':     AvatarKey TumorMarkerInd  TumorMarkerKey AgeAtTumorMarkerTest  \
#  0     A028331            Yes           25277               69.989
#  1     A028339            Yes           25294               29.208
#  2     A029217            Yes          277898               58.685
#  3     A029224            Yes          277900               71.553
#  4     A029224            Yes          277901               71.666
#  ..        ...            ...             ...                  ...
#  298   A039956            Yes          271384               63.882
#  299   A039956            Yes          271385               63.959
#  300   A039956            Yes          271386               64.036
#  301   A039977            Yes          271426               55.438
#  302   A040114            Yes          271453               70.263
#
#             AgeAtTumorMarkerTestFlag YearOfTumorMarkerTest  \
#  0    Age derived from complete date                  2017
#  1    Age derived from complete date                  2018
#  2    Age derived from complete date                  2021
#  3    Age derived from complete date                  2022
#  4    Age derived from complete date                  2022
#  ..                              ...                   ...
#  298  Age derived from complete date                  2021
#  299  Age derived from complete date                  2021
#  300  Age derived from complete date                  2021
#  301  Age derived from complete date                  2021
#  302  Age derived from complete date                  2021
#
#                                      TMarkerTest           TMarkerResult  \
#  0                          Flow Cytometry Panel  Unknown/Not Applicable
#  1                          Flow Cytometry Panel  Unknown/Not Applicable
#  2    Prostate specific Antigen (PSA expression)                   Value
#  3    Prostate specific Antigen (PSA expression)                   Value
#  4    Prostate specific Antigen (PSA expression)                   Value
#  ..                                          ...                     ...
#  298                              CEA expression                   Value
#  299                              CEA expression                   Value
#  300                              CEA expression                   Value
#  301                        Flow Cytometry Panel  Unknown/Not Applicable
#  302  Prostate specific Antigen (PSA expression)                   Value
#
#           TMarkerResultValue         TMarkerValueUOM     TMarkerPercentStain  \
#  0    Unknown/Not Applicable  Unknown/Not Applicable  Unknown/Not Applicable
#  1    Unknown/Not Applicable  Unknown/Not Applicable  Unknown/Not Applicable
#  2                      0.68                   ng/mL  Unknown/Not Applicable
#  3                      0.85                   ng/mL  Unknown/Not Applicable
#  4                      1.08                   ng/mL  Unknown/Not Applicable
#  ..                      ...                     ...                     ...
#  298                     1.7                   ng/mL  Unknown/Not Applicable
#  299                     2.1                   ng/mL  Unknown/Not Applicable
#  300                     2.2                   ng/mL  Unknown/Not Applicable
#  301  Unknown/Not Applicable  Unknown/Not Applicable  Unknown/Not Applicable
#  302                    4.87                   ng/mL  Unknown/Not Applicable
#
#      TMarkerPercentStainResultValue       TMarkerRangeIndicator  \
#  0           Unknown/Not Applicable      Unknown/Not Applicable
#  1           Unknown/Not Applicable      Unknown/Not Applicable
#  2           Unknown/Not Applicable  WNL (Within Normal Limits)
#  3           Unknown/Not Applicable  WNL (Within Normal Limits)
#  4           Unknown/Not Applicable  WNL (Within Normal Limits)
#  ..                             ...                         ...
#  298         Unknown/Not Applicable  WNL (Within Normal Limits)
#  299         Unknown/Not Applicable  WNL (Within Normal Limits)
#  300         Unknown/Not Applicable  WNL (Within Normal Limits)
#  301         Unknown/Not Applicable      Unknown/Not Applicable
#  302         Unknown/Not Applicable  WNL (Within Normal Limits)
#
#              TMarkerLowRange        TMarkerHighRange
#  0    Unknown/Not Applicable  Unknown/Not Applicable
#  1    Unknown/Not Applicable  Unknown/Not Applicable
#  2    Unknown/Not Applicable                    3.50
#  3    Unknown/Not Applicable                    6.50
#  4    Unknown/Not Applicable                    6.50
#  ..                      ...                     ...
#  298  Unknown/Not Applicable                    5.00
#  299  Unknown/Not Applicable                    5.00
#  300  Unknown/Not Applicable                    5.00
#  301  Unknown/Not Applicable  Unknown/Not Applicable
#  302  Unknown/Not Applicable                    6.50
#
#  [303 rows x 15 columns],
#  'CytogeneticAbnormalities':     AvatarKey CytogenAbnormInd      AgeAtCytogenAbnorm  \
#  0     A006690               No  Unknown/Not Applicable
#  1     A006745               No  Unknown/Not Applicable
#  2     A006746               No  Unknown/Not Applicable
#  3     A006747              Yes                  40.381
#  4     A006747              Yes                  40.381
#  ..        ...              ...                     ...
#  417   A049247               No  Unknown/Not Applicable
#  418   A049248               No  Unknown/Not Applicable
#  419   A049250               No  Unknown/Not Applicable
#  420   A049252              Yes                  56.995
#  421   A049252              Yes                  56.995
#
#               AgeAtCytogenAbnormFlag     YearOfCytogenAbnorm  \
#  0            Unknown/Not Applicable  Unknown/Not Applicable
#  1            Unknown/Not Applicable  Unknown/Not Applicable
#  2            Unknown/Not Applicable  Unknown/Not Applicable
#  3    Age derived from complete date                    2017
#  4    Age derived from complete date                    2017
#  ..                              ...                     ...
#  417          Unknown/Not Applicable  Unknown/Not Applicable
#  418          Unknown/Not Applicable  Unknown/Not Applicable
#  419          Unknown/Not Applicable  Unknown/Not Applicable
#  420  Age derived from complete date                    2023
#  421  Age derived from complete date                    2023
#
#            CytogenAbnormName     CytogenAbnormResult
#  0    Unknown/Not Applicable  Unknown/Not Applicable
#  1    Unknown/Not Applicable  Unknown/Not Applicable
#  2    Unknown/Not Applicable  Unknown/Not Applicable
#  3                     Other                Positive
#  4                   t(8;21)                Positive
#  ..                      ...                     ...
#  417  Unknown/Not Applicable  Unknown/Not Applicable
#  418  Unknown/Not Applicable  Unknown/Not Applicable
#  419  Unknown/Not Applicable  Unknown/Not Applicable
#  420                 inv(16)                Positive
#  421                   Other                Positive
#
#  [422 rows x 7 columns],
#  'Diagnosis':     AvatarKey AgeAtFirstContact           AgeAtFirstContactFlag  \
#  0     A006690            59.556  Age derived from complete date
#  1     A006690            59.556  Age derived from complete date
#  2     A039952            32.523  Age derived from complete date
#  3     A039953            50.332  Age derived from complete date
#  4     A039956            59.893  Age derived from complete date
#  ..        ...               ...                             ...
#  157   A049229            58.622  Age derived from complete date
#  158   A049231            38.123  Age derived from complete date
#  159   A049233            66.233  Age derived from complete date
#  160   A049236            76.964  Age derived from complete date
#  161   A049237            60.093  Age derived from complete date
#
#       YearOfFirstContact AgeAtDiagnosis              AgeAtDiagnosisFlag  \
#  0                  2015         50.512  Age derived from complete date
#  1                  2015         59.474  Age derived from complete date
#  2                  2003         32.523  Age derived from complete date
#  3                  2016         50.332  Age derived from complete date
#  4                  2017         59.893  Age derived from complete date
#  ..                  ...            ...                             ...
#  157                2019         58.622  Age derived from complete date
#  158                2020         38.123  Age derived from complete date
#  159                2021         66.233  Age derived from complete date
#  160                2021         76.964  Age derived from complete date
#  161                2020         60.093  Age derived from complete date
#
#       YearOfDiagnosis PrimaryDiagnosisSiteCode      PrimaryDiagnosisSite  \
#  0               2006                    C42.1               Bone marrow
#  1               2015                    C15.5  Lower third of esophagus
#  2               2003                    C42.1               Bone marrow
#  3               2016                    C42.1               Bone marrow
#  4               2017                    C42.1               Bone marrow
#  ..               ...                      ...                       ...
#  157             2019                    C42.1               Bone marrow
#  158             2020                    C42.1               Bone marrow
#  159             2021                    C42.1               Bone marrow
#  160             2021                    C42.1               Bone marrow
#  161             2020                    C42.1               Bone marrow
#
#                       Laterality  ... AgeAtOtherStagingSystemFlag  \
#  0    Organ is not a paired site  ...    Age Unknown/Not Recorded
#  1    Organ is not a paired site  ...    Age Unknown/Not Recorded
#  2    Organ is not a paired site  ...    Age Unknown/Not Recorded
#  3    Organ is not a paired site  ...    Age Unknown/Not Recorded
#  4    Organ is not a paired site  ...    Age Unknown/Not Recorded
#  ..                          ...  ...                         ...
#  157  Organ is not a paired site  ...    Age Unknown/Not Recorded
#  158  Organ is not a paired site  ...    Age Unknown/Not Recorded
#  159  Organ is not a paired site  ...    Age Unknown/Not Recorded
#  160  Organ is not a paired site  ...    Age Unknown/Not Recorded
#  161  Organ is not a paired site  ...    Age Unknown/Not Recorded
#
#       YearOfOtherStagingSystem      OtherStagingSystem       OtherStagingValue  \
#  0    Age Unknown/Not Recorded  Unknown/Not Applicable  Unknown/Not Applicable
#  1    Age Unknown/Not Recorded  Unknown/Not Applicable  Unknown/Not Applicable
#  2    Age Unknown/Not Recorded  Unknown/Not Applicable  Unknown/Not Applicable
#  3    Age Unknown/Not Recorded  Unknown/Not Applicable  Unknown/Not Applicable
#  4    Age Unknown/Not Recorded  Unknown/Not Applicable  Unknown/Not Applicable
#  ..                        ...                     ...                     ...
#  157  Age Unknown/Not Recorded  Unknown/Not Applicable  Unknown/Not Applicable
#  158  Age Unknown/Not Recorded  Unknown/Not Applicable  Unknown/Not Applicable
#  159  Age Unknown/Not Recorded  Unknown/Not Applicable  Unknown/Not Applicable
#  160  Age Unknown/Not Recorded  Unknown/Not Applicable  Unknown/Not Applicable
#  161  Age Unknown/Not Recorded  Unknown/Not Applicable  Unknown/Not Applicable
#
#      CurrentlySeenForPrimaryOrRecurr AgeAtPerformanceStatusAtDiagnosis  \
#  0               Progressive Disease          Age Unknown/Not Recorded
#  1                 Primary Diagnosis          Age Unknown/Not Recorded
#  2                 Primary Diagnosis          Age Unknown/Not Recorded
#  3                 Primary Diagnosis          Age Unknown/Not Recorded
#  4                 Primary Diagnosis          Age Unknown/Not Recorded
#  ..                              ...                               ...
#  157               Primary Diagnosis          Age Unknown/Not Recorded
#  158               Primary Diagnosis                            38.167
#  159               Primary Diagnosis          Age Unknown/Not Recorded
#  160               Primary Diagnosis                            77.003
#  161               Primary Diagnosis          Age Unknown/Not Recorded
#
#      AgeAtPerformanceStatusAtDiagnosisFlag YearOfPerformanceStatusAtDiagnosis  \
#  0                Age Unknown/Not Recorded           Age Unknown/Not Recorded
#  1                Age Unknown/Not Recorded           Age Unknown/Not Recorded
#  2                Age Unknown/Not Recorded           Age Unknown/Not Recorded
#  3                Age Unknown/Not Recorded           Age Unknown/Not Recorded
#  4                Age Unknown/Not Recorded           Age Unknown/Not Recorded
#  ..                                    ...                                ...
#  157              Age Unknown/Not Recorded           Age Unknown/Not Recorded
#  158        Age derived from complete date                               2020
#  159              Age Unknown/Not Recorded           Age Unknown/Not Recorded
#  160        Age derived from complete date                               2021
#  161              Age Unknown/Not Recorded           Age Unknown/Not Recorded
#
#        PerformStatusAtDiagnosis PerformStatusAtDiagnosisScale
#  0        Unknown/Not Performed         Unknown/Not Performed
#  1        Unknown/Not Performed         Unknown/Not Performed
#  2        Unknown/Not Performed         Unknown/Not Performed
#  3        Unknown/Not Performed         Unknown/Not Performed
#  4        Unknown/Not Performed         Unknown/Not Performed
#  ..                         ...                           ...
#  157      Unknown/Not Performed         Unknown/Not Performed
#  158  ECOG 2 / Karnofsky 60-70%       ECOG Performance status
#  159      Unknown/Not Performed         Unknown/Not Performed
#  160  ECOG 1 / Karnofsky 80-90%       ECOG Performance status
#  161      Unknown/Not Performed         Unknown/Not Performed
#
#  [162 rows x 41 columns],
#  'VitalStatus':     AvatarKey VitalStatus AgeAtLastContact            AgeAtLastContactFlag  \
#  0     A006690       Alive           66.710  Age derived from complete date
#  1     A006745        Dead           77.901  Age derived from complete date
#  2     A006746        Dead           81.274  Age derived from complete date
#  3     A006747        Dead           40.981  Age derived from complete date
#  4     A006748       Alive           59.115  Age derived from complete date
#  ..        ...         ...              ...                             ...
#  141   A049246       Alive           54.244  Age derived from complete date
#  142   A049247        Dead           80.510  Age derived from complete date
#  143   A049248       Alive           74.389  Age derived from complete date
#  144   A049250       Alive           61.660  Age derived from complete date
#  145   A049252        Dead           58.099  Age derived from complete date
#
#       YearOfLastContact              AgeAtDeath  \
#  0                 2022  Unknown/Not Applicable
#  1                 2017                  77.901
#  2                 2018                  81.274
#  3                 2017                  40.981
#  4                 2023  Unknown/Not Applicable
#  ..                 ...                     ...
#  141               2025  Unknown/Not Applicable
#  142               2024                  80.510
#  143               2024  Unknown/Not Applicable
#  144               2024  Unknown/Not Applicable
#  145               2025                  58.099
#
#                       AgeAtDeathFlag             YearOfDeath  \
#  0            Unknown/Not Applicable  Unknown/Not Applicable
#  1    Age derived from complete date                    2017
#  2    Age derived from complete date                    2018
#  3    Age derived from complete date                    2017
#  4            Unknown/Not Applicable  Unknown/Not Applicable
#  ..                              ...                     ...
#  141          Unknown/Not Applicable  Unknown/Not Applicable
#  142  Age derived from complete date                    2024
#  143          Unknown/Not Applicable  Unknown/Not Applicable
#  144          Unknown/Not Applicable  Unknown/Not Applicable
#  145  Age derived from complete date                    2025
#
#                 CauseOfDeath VitalStatusConfirmed  \
#  0    Unknown/Not Applicable                  Yes
#  1             Due to Cancer                  Yes
#  2             Due to Cancer                  Yes
#  3    Probably Due to Cancer                  Yes
#  4    Unknown/Not Applicable                  Yes
#  ..                      ...                  ...
#  141  Unknown/Not Applicable                  Yes
#  142           Due to Cancer                  Yes
#  143  Unknown/Not Applicable                  Yes
#  144  Unknown/Not Applicable                  Yes
#  145  Unknown/Not Applicable                  Yes
#
#                                       VitalStatusSource
#  0    Source Documentation (e.g. Death Certificate, ...
#  1    Source Documentation (e.g. Death Certificate, ...
#  2                Source System (e.g. SSDI, Legacy.com)
#  3    Source Documentation (e.g. Death Certificate, ...
#  4    Source Documentation (e.g. Death Certificate, ...
#  ..                                                 ...
#  141  Source Documentation (e.g. Death Certificate, ...
#  142  Source Documentation (e.g. Death Certificate, ...
#  143  Source Documentation (e.g. Death Certificate, ...
#  144  Source Documentation (e.g. Death Certificate, ...
#  145                         Automated Source Data Feed
#
#  [146 rows x 11 columns],
#  'ClinicalMolLinkage':     AvatarKey Site Tumor/Germline           WES    WES Batch        RNASeq  \
#  0     A039956  UVA          Tumor  FT-SA158775D  FT-SPN03600  FT-SA158775R
#  1     A039970  UVA          Tumor  FT-SA158776D  FT-SPN03600  FT-SA158776R
#  2     A039973  UVA          Tumor  FT-SA158769D  FT-SPN03600  FT-SA158769R
#  3     A039977  UVA          Tumor  FT-SA158771D  FT-SPN03600  FT-SA158771R
#  4     A049227  UVA          Tumor  FT-SA276601D  FT-SPN05800  FT-SA276601R
#  ..        ...  ...            ...           ...          ...           ...
#  141   A049250  UVA          Tumor  FT-SA276594D  FT-SPN05800  FT-SA276594R
#  142   A039962  UVA          Tumor  FT-SA158754D  FT-SPN03600  FT-SA158754R
#  143   A039980  UVA          Tumor  FT-SA158757D  FT-SPN03600  FT-SA158757R
#  144   A040093  UVA          Tumor  FT-SA159834D  FT-SPN03639  FT-SA159834R
#  145   A040096  UVA          Tumor  FT-SA159836D  FT-SPN03639  FT-SA159836R
#
#         RNA Batch     DiseaseType SpecimenSiteOfOrigin  \
#  0    FT-SPN03601  HEM - Leukemia          Bone marrow
#  1    FT-SPN03601  HEM - Leukemia          Bone marrow
#  2    FT-SPN03601  HEM - Leukemia          Bone marrow
#  3    FT-SPN03601  HEM - Leukemia          Bone marrow
#  4    FT-SPN05799  HEM - Leukemia          Bone marrow
#  ..           ...             ...                  ...
#  141  FT-SPN05799  HEM - Leukemia          Bone marrow
#  142  FT-SPN03601  HEM - Leukemia          Bone marrow
#  143  FT-SPN03601  HEM - Leukemia          Bone marrow
#  144  FT-SPN03640  HEM - Leukemia          Bone marrow
#  145  FT-SPN03640  HEM - Leukemia          Bone marrow
#
#      SpecimenSiteOfCollection Primary/Met       SpecimenType  \
#  0                      Blood     Primary  PBMC-viable cells
#  1                      Blood     Primary  PBMC-viable cells
#  2                      Blood     Primary  PBMC-viable cells
#  3                      Blood     Primary  PBMC-viable cells
#  4                      Blood     Primary               MNCs
#  ..                       ...         ...                ...
#  141                    Blood     Primary               MNCs
#  142              Bone marrow     Primary   BMC-viable cells
#  143              Bone marrow     Primary   BMC-viable cells
#  144              Bone Marrow     Primary    BMC-Cell Pellet
#  145              Bone Marrow     Primary    BMC-Cell Pellet
#
#      SpecimenDerivativeSource  \
#  0                      Blood
#  1                      Blood
#  2                      Blood
#  3                      Blood
#  4                      Blood
#  ..                       ...
#  141                    Blood
#  142              Bone Marrow
#  143              Bone Marrow
#  144                    Blood
#  145                    Blood
#
#                                      Histology/Behavior PreservationMethod  \
#  0         98113 B lymphoblastic leukemia/lymphoma, NOS           FBS/DMSO
#  1                            98013 Acute leukemia, NOS           FBS/DMSO
#  2    98233 Chronic lymphocytic leukemia/small lymph...           FBS/DMSO
#  3                    98613 Acute myeloid leukemia, NOS           FBS/DMSO
#  4                    98613 Acute myeloid leukemia, NOS           FBS/DMSO
#  ..                                                 ...                ...
#  141                  98613 Acute myeloid leukemia, NOS             Frozen
#  142                  98613 Acute myeloid leukemia, NOS           FBS/DMSO
#  143  98663 Acute promyelocytic leukemia, t(15;17)(q...           FBS/DMSO
#  144  98233 Chronic lymphocytic leukemia/small lymph...             Frozen
#  145                98633 Chronic myeloid leukemia, NOS             Frozen
#
#       % Tumor Content Age At Specimen Collection SpecimenSiteOfOriginRollUp  \
#  0                 88                     60.550                Bone marrow
#  1                 51                     47.930                Bone marrow
#  2                 96                     67.630                Bone marrow
#  3                 20                     55.300                Bone marrow
#  4                 40                     76.900                Bone marrow
#  ..               ...                        ...                        ...
#  141               96                     60.460                Bone marrow
#  142               37                     67.540                Bone marrow
#  143               22                     39.420                Bone marrow
#  144               34                     65.380                Bone marrow
#  145               71                     21.850                Bone marrow
#
#       SampleAgeInDays   ORIENSpecimenID
#  0               1628    UVA-H-M-006042
#  1                900    UVA-H-M-006044
#  2                588    UVA-H-M-006026
#  3                417    UVA-H-M-006030
#  4               1234  UVA-HWS-M-007700
#  ..               ...               ...
#  141              380  UVA-HWS-M-007692
#  142             1267    UVA-H-M-006022
#  143               41    UVA-H-M-006062
#  144             1695    UVA-H-M-006066
#  145             1614    UVA-H-M-006090
#
#  [146 rows x 20 columns],
#  'Medications':     AvatarKey MedicationInd      MedReasonNoneGiven  \
#  0     A039958           Yes  Unknown/Not Applicable
#  1     A039959           Yes  Unknown/Not Applicable
#  2     A039961           Yes  Unknown/Not Applicable
#  3     A039962           Yes  Unknown/Not Applicable
#  4     A039962           Yes  Unknown/Not Applicable
#  ..        ...           ...                     ...
#  661   A039956           Yes  Unknown/Not Applicable
#  662   A039958           Yes  Unknown/Not Applicable
#  663   A039958           Yes  Unknown/Not Applicable
#  664   A039958           Yes  Unknown/Not Applicable
#  665   A039958           Yes  Unknown/Not Applicable
#
#      MedPrimaryDiagnosisSiteCode MedPrimaryDiagnosisSite  \
#  0                         C42.1             Bone marrow
#  1                         C42.1             Bone marrow
#  2                         C42.1             Bone marrow
#  3                         C42.1             Bone marrow
#  4                         C42.1             Bone marrow
#  ..                          ...                     ...
#  661                       C42.1             Bone marrow
#  662                       C42.1             Bone marrow
#  663                       C42.1             Bone marrow
#  664                       C42.1             Bone marrow
#  665                       C42.1             Bone marrow
#
#                  Medication       MedLineRegimen AgeAtMedStart  \
#  0               Venetoclax          Fourth Line        74.016
#  1                Ibrutinib          Second Line        67.060
#  2             Methotrexate          Second Line        34.471
#  3              Azacitidine          Second Line        67.586
#  4               Decitabine  Adjuvant/First Line        66.970
#  ..                     ...                  ...           ...
#  661    Vincristine Sulfate  Adjuvant/First Line        59.923
#  662       Cyclophosphamide          Second Line        63.395
#  663  Fludarabine Phosphate          Second Line        63.395
#  664              Ibrutinib           Third Line        67.066
#  665              Rituximab          Second Line        63.395
#
#                    AgeAtMedStartFlag YearOfMedStart MedContinuing  \
#  0    Age derived from complete date           2021           Yes
#  1    Age derived from complete date           2016            No
#  2    Age derived from complete date           2017            No
#  3    Age derived from complete date           2019            No
#  4    Age derived from complete date           2018            No
#  ..                              ...            ...           ...
#  661  Age derived from complete date           2017            No
#  662  Age derived from complete date           2011            No
#  663  Age derived from complete date           2011            No
#  664  Age derived from complete date           2014            No
#  665  Age derived from complete date           2011            No
#
#                 AgeAtMedStop                AgeAtMedStopFlag  \
#  0    Unknown/Not Applicable          Unknown/Not Applicable
#  1                    68.518  Age derived from complete date
#  2                    37.244  Age derived from complete date
#  3                    67.690  Age derived from complete date
#  4                    67.460  Age derived from complete date
#  ..                      ...                             ...
#  661                  60.488  Age derived from complete date
#  662                  63.477  Age derived from complete date
#  663                  63.477  Age derived from complete date
#  664                  74.016  Age derived from complete date
#  665                  63.589  Age derived from complete date
#
#                YearOfMedStop    ChangeOfTreatment  \
#  0    Unknown/Not Applicable                   No
#  1                      2017  Completed Treatment
#  2                      2020  Completed Treatment
#  3                      2019  Completed Treatment
#  4                      2019  Completed Treatment
#  ..                      ...                  ...
#  661                    2018  Completed Treatment
#  662                    2011  Completed Treatment
#  663                    2011  Completed Treatment
#  664                    2021  Completed Treatment
#  665                    2011  Completed Treatment
#
#                              SystemicSurgerySequence
#  0    No systemic therapy and/or surgical procedures
#  1    No systemic therapy and/or surgical procedures
#  2    No systemic therapy and/or surgical procedures
#  3    No systemic therapy and/or surgical procedures
#  4    No systemic therapy and/or surgical procedures
#  ..                                              ...
#  661  No systemic therapy and/or surgical procedures
#  662  No systemic therapy and/or surgical procedures
#  663  No systemic therapy and/or surgical procedures
#  664  No systemic therapy and/or surgical procedures
#  665  No systemic therapy and/or surgical procedures
#
#  [666 rows x 16 columns],
#  'PatientMaster':     AvatarKey AgeAtClinicalRecordCreation  YearOfClinicalRecordCreation  \
#  0     A006690                      61.378                          2017
#  1     A006745                      77.266                          2017
#  2     A006746                      85.356                          2022
#  3     A006747                      40.556                          2017
#  4     A006748                      52.729                          2017
#  ..        ...                         ...                           ...
#  141   A049246                      54.036                          2024
#  142   A049247                      81.137                          2024
#  143   A049248                      74.216                          2024
#  144   A049250                      61.507                          2024
#  145   A049252                      57.827                          2024
#
#          Sex                       Race                  Ethnicity
#  0      Male                      White  Non-Spanish; Non-Hispanic
#  1      Male                      White  Non-Spanish; Non-Hispanic
#  2      Male                      White  Non-Spanish; Non-Hispanic
#  3      Male                      White  Non-Spanish; Non-Hispanic
#  4      Male                      White  Non-Spanish; Non-Hispanic
#  ..      ...                        ...                        ...
#  141    Male  Black or African American  Non-Spanish; Non-Hispanic
#  142  Female                      White  Non-Spanish; Non-Hispanic
#  143    Male                      White  Non-Spanish; Non-Hispanic
#  144  Female                      White  Non-Spanish; Non-Hispanic
#  145    Male  Black or African American  Non-Spanish; Non-Hispanic
#
#  [146 rows x 6 columns],
#  'PatientHistory':     AvatarKey AgeAtLastUpdate  YearOfLastUpdate SmokingStatus   AlcoholUse  \
#  0     A006690          66.332              2022         Never        Never
#  1     A006745          82.293              2022         Never      Current
#  2     A006746          85.419              2022   Former/Ever      Current
#  3     A006747          45.567              2022   Former/Ever        Never
#  4     A006748          57.742              2022   Former/Ever        Never
#  ..        ...             ...               ...           ...          ...
#  141   A049246          54.260              2025   Former/Ever  Former/Ever
#  142   A049247          81.362              2025   Former/Ever        Never
#  143   A049248          74.441              2025         Never        Never
#  144   A049250          61.732              2025         Never        Never
#  145   A049252          58.052              2025   Former/Ever  Former/Ever
#
#      PreOrNonMalignantConditionInd PreExistAdenoma PreExistAplasticAnemia  \
#  0                              No              No                     No
#  1                              No              No                     No
#  2                              No              No                     No
#  3                              No              No                     No
#  4                              No              No                     No
#  ..                            ...             ...                    ...
#  141                            No              No                     No
#  142                            No              No                     No
#  143                            No              No                     No
#  144                            No              No                     No
#  145                            No              No                     No
#
#      PreExistAtaxiaTelangiectasia PreExistBarrettEsophagus  ...  \
#  0                             No                       No  ...
#  1                             No                       No  ...
#  2                             No                       No  ...
#  3                             No                       No  ...
#  4                             No                       No  ...
#  ..                           ...                      ...  ...
#  141                           No                       No  ...
#  142                           No                       No  ...
#  143                           No                       No  ...
#  144                           No                       No  ...
#  145                           No                       No  ...
#
#      LiverDrugToxicityInd KidneyDrugToxicityInd FatigueDrugToxicityInd  \
#  0                     No                    No                     No
#  1                     No                    No                     No
#  2                     No                    No                     No
#  3                     No                    No                     No
#  4                     No                    No                     No
#  ..                   ...                   ...                    ...
#  141                   No                    No                     No
#  142                   No                    No                     No
#  143                   No                    No                     No
#  144                   No                    No                     No
#  145                   No                    No                     No
#
#      NoDrugToxicityInd OrganTransplantInd    AgeAtOrganTransplant  \
#  0                 Yes                 No  Unknown/Not Applicable
#  1                 Yes                 No  Unknown/Not Applicable
#  2                 Yes                 No  Unknown/Not Applicable
#  3                 Yes                 No  Unknown/Not Applicable
#  4                 Yes                 No  Unknown/Not Applicable
#  ..                ...                ...                     ...
#  141               Yes                 No  Unknown/Not Applicable
#  142               Yes                 No  Unknown/Not Applicable
#  143               Yes                 No  Unknown/Not Applicable
#  144               Yes                 No  Unknown/Not Applicable
#  145               Yes                 No  Unknown/Not Applicable
#
#      AgeAtOrganTransplantFlag   YearOfOrganTransplant     OrganTransplantSite  \
#  0     Unknown/Not Applicable  Unknown/Not Applicable  Unknown/Not Applicable
#  1     Unknown/Not Applicable  Unknown/Not Applicable  Unknown/Not Applicable
#  2     Unknown/Not Applicable  Unknown/Not Applicable  Unknown/Not Applicable
#  3     Unknown/Not Applicable  Unknown/Not Applicable  Unknown/Not Applicable
#  4     Unknown/Not Applicable  Unknown/Not Applicable  Unknown/Not Applicable
#  ..                       ...                     ...                     ...
#  141   Unknown/Not Applicable  Unknown/Not Applicable  Unknown/Not Applicable
#  142   Unknown/Not Applicable  Unknown/Not Applicable  Unknown/Not Applicable
#  143   Unknown/Not Applicable  Unknown/Not Applicable  Unknown/Not Applicable
#  144   Unknown/Not Applicable  Unknown/Not Applicable  Unknown/Not Applicable
#  145   Unknown/Not Applicable  Unknown/Not Applicable  Unknown/Not Applicable
#
#      OnDrugTrialInd
#  0               No
#  1               No
#  2               No
#  3               No
#  4               No
#  ..             ...
#  141             No
#  142             No
#  143             No
#  144             No
#  145             No
#
#  [146 rows x 91 columns],
#  'StemCellTransplant':     AvatarKey SCTInd SCTPrimaryDiagnosisSiteCode SCTPrimaryDiagnosisSite  \
#  0     A028334     No      Unknown/Not Applicable  Unknown/Not Applicable
#  1     A028335     No      Unknown/Not Applicable  Unknown/Not Applicable
#  2     A028337     No      Unknown/Not Applicable  Unknown/Not Applicable
#  3     A028339     No      Unknown/Not Applicable  Unknown/Not Applicable
#  4     A028340    Yes                       C42.1             Bone marrow
#  ..        ...    ...                         ...                     ...
#  141   A049246    Yes                       C42.1             Bone marrow
#  142   A049247     No      Unknown/Not Applicable  Unknown/Not Applicable
#  143   A049248    Yes                       C42.1             Bone marrow
#  144   A049250     No      Unknown/Not Applicable  Unknown/Not Applicable
#  145   A049252    Yes                       C42.1             Bone marrow
#
#              AgeAtTransplant             AgeAtTransplantFlag  \
#  0    Unknown/Not Applicable          Unknown/Not Applicable
#  1    Unknown/Not Applicable          Unknown/Not Applicable
#  2    Unknown/Not Applicable          Unknown/Not Applicable
#  3    Unknown/Not Applicable          Unknown/Not Applicable
#  4                    42.266  Age derived from complete date
#  ..                      ...                             ...
#  141                  53.074  Age derived from complete date
#  142  Unknown/Not Applicable          Unknown/Not Applicable
#  143                  73.888  Age derived from complete date
#  144  Unknown/Not Applicable          Unknown/Not Applicable
#  145                  57.441  Age derived from complete date
#
#             YearOfTransplant          TransplantType    TransplantCellSource  \
#  0    Unknown/Not Applicable  Unknown/Not Applicable  Unknown/Not Applicable
#  1    Unknown/Not Applicable  Unknown/Not Applicable  Unknown/Not Applicable
#  2    Unknown/Not Applicable  Unknown/Not Applicable  Unknown/Not Applicable
#  3    Unknown/Not Applicable  Unknown/Not Applicable  Unknown/Not Applicable
#  4                      2019         Allogeneic, NOS             Bone marrow
#  ..                      ...                     ...                     ...
#  141                    2023    Unknown/Not Reported        Peripheral Blood
#  142  Unknown/Not Applicable  Unknown/Not Applicable  Unknown/Not Applicable
#  143                    2024         Allogeneic, NOS        Peripheral Blood
#  144  Unknown/Not Applicable  Unknown/Not Applicable  Unknown/Not Applicable
#  145                    2024    Unknown/Not Reported        Peripheral Blood
#
#           AgeAtPostTransStatus  AgeAtPostTransStatusFlag  \
#  0      Unknown/Not Applicable    Unknown/Not Applicable
#  1      Unknown/Not Applicable    Unknown/Not Applicable
#  2      Unknown/Not Applicable    Unknown/Not Applicable
#  3      Unknown/Not Applicable    Unknown/Not Applicable
#  4    Age Unknown/Not Recorded  Age Unknown/Not Recorded
#  ..                        ...                       ...
#  141  Age Unknown/Not Recorded  Age Unknown/Not Recorded
#  142    Unknown/Not Applicable    Unknown/Not Applicable
#  143  Age Unknown/Not Recorded  Age Unknown/Not Recorded
#  144    Unknown/Not Applicable    Unknown/Not Applicable
#  145  Age Unknown/Not Recorded  Age Unknown/Not Recorded
#
#          YearOfPostTransStatus              MRDTestInd            AgeAtMRDTest  \
#  0      Unknown/Not Applicable  Unknown/Not Applicable  Unknown/Not Applicable
#  1      Unknown/Not Applicable  Unknown/Not Applicable  Unknown/Not Applicable
#  2      Unknown/Not Applicable  Unknown/Not Applicable  Unknown/Not Applicable
#  3      Unknown/Not Applicable  Unknown/Not Applicable  Unknown/Not Applicable
#  4    Age Unknown/Not Recorded  Unknown/Not Applicable  Unknown/Not Applicable
#  ..                        ...                     ...                     ...
#  141  Age Unknown/Not Recorded  Unknown/Not Applicable  Unknown/Not Applicable
#  142    Unknown/Not Applicable  Unknown/Not Applicable  Unknown/Not Applicable
#  143  Age Unknown/Not Recorded  Unknown/Not Applicable  Unknown/Not Applicable
#  144    Unknown/Not Applicable  Unknown/Not Applicable  Unknown/Not Applicable
#  145  Age Unknown/Not Recorded  Unknown/Not Applicable  Unknown/Not Applicable
#
#             AgeAtMRDTestFlag           YearOfMRDTest
#  0    Unknown/Not Applicable  Unknown/Not Applicable
#  1    Unknown/Not Applicable  Unknown/Not Applicable
#  2    Unknown/Not Applicable  Unknown/Not Applicable
#  3    Unknown/Not Applicable  Unknown/Not Applicable
#  4    Unknown/Not Applicable  Unknown/Not Applicable
#  ..                      ...                     ...
#  141  Unknown/Not Applicable  Unknown/Not Applicable
#  142  Unknown/Not Applicable  Unknown/Not Applicable
#  143  Unknown/Not Applicable  Unknown/Not Applicable
#  144  Unknown/Not Applicable  Unknown/Not Applicable
#  145  Unknown/Not Applicable  Unknown/Not Applicable
#
#  [146 rows x 16 columns],
#  'Outcomes':     AvatarKey OutcomesPrimaryDiagnosisSiteCode OutcomesPrimaryDiagnosisSite  \
#  0     A030981                            C42.1                  Bone marrow
#  1     A030982                            C42.1                  Bone marrow
#  2     A030983                            C42.1                  Bone marrow
#  3     A030984                            C42.1                  Bone marrow
#  4     A030985                            C42.1                  Bone marrow
#  ..        ...                              ...                          ...
#  176   A040109                            C42.1                  Bone marrow
#  177   A040111                            C42.1                  Bone marrow
#  178   A040112                            C42.1                  Bone marrow
#  179   A040113                            C42.1                  Bone marrow
#  180   A040114                            C42.1                  Bone marrow
#
#                 ProgRecurInd          AgeAtProgRecur  \
#  0    Unknown/Not Applicable  Unknown/Not Applicable
#  1               Progression                  74.995
#  2    Unknown/Not Applicable  Unknown/Not Applicable
#  3    Unknown/Not Applicable  Unknown/Not Applicable
#  4    Unknown/Not Applicable  Unknown/Not Applicable
#  ..                      ...                     ...
#  176             Progression                  56.504
#  177  Unknown/Not Applicable  Unknown/Not Applicable
#  178  Unknown/Not Applicable  Unknown/Not Applicable
#  179  Unknown/Not Applicable  Unknown/Not Applicable
#  180  Unknown/Not Applicable  Unknown/Not Applicable
#
#                   AgeAtProgRecurFlag         YearOfProgRecur  \
#  0            Unknown/Not Applicable  Unknown/Not Applicable
#  1    Age derived from complete date                    2021
#  2            Unknown/Not Applicable  Unknown/Not Applicable
#  3            Unknown/Not Applicable  Unknown/Not Applicable
#  4            Unknown/Not Applicable  Unknown/Not Applicable
#  ..                              ...                     ...
#  176  Age derived from complete date                    2020
#  177          Unknown/Not Applicable  Unknown/Not Applicable
#  178          Unknown/Not Applicable  Unknown/Not Applicable
#  179          Unknown/Not Applicable  Unknown/Not Applicable
#  180          Unknown/Not Applicable  Unknown/Not Applicable
#
#      ProgSourceFromTumorMarker ProgSourceFromImaging ProgSourceFromPathConfirm  \
#  0                          No                    No                        No
#  1                          No                    No                        No
#  2                          No                    No                        No
#  3                          No                    No                        No
#  4                          No                    No                        No
#  ..                        ...                   ...                       ...
#  176                        No                    No                        No
#  177                        No                    No                        No
#  178                        No                    No                        No
#  179                        No                    No                        No
#  180                        No                    No                        No
#
#       ... BestRespFromClinicalRecord AgeAtPerformStatusMostRecent  \
#  0    ...                        Yes                       63.534
#  1    ...                        Yes                       77.315
#  2    ...                        Yes                       71.047
#  3    ...                        Yes                       68.814
#  4    ...                        Yes                       68.518
#  ..   ...                        ...                          ...
#  176  ...                        Yes                       58.751
#  177  ...                        Yes                       75.447
#  178  ...                        Yes                       68.014
#  179  ...                        Yes                       77.800
#  180  ...                        Yes                       70.863
#
#      AgeAtPerformStatusMostRecentFlag YearOfPerformStatusMostRecent  \
#  0     Age derived from complete date                          2016
#  1     Age derived from complete date                          2023
#  2     Age derived from complete date                          2018
#  3     Age derived from complete date                          2018
#  4     Age derived from complete date                          2018
#  ..                               ...                           ...
#  176   Age derived from complete date                          2023
#  177   Age derived from complete date                          2022
#  178   Age derived from complete date                          2021
#  179   Age derived from complete date                          2021
#  180   Age derived from complete date                          2022
#
#         PerformStatusMostRecent PerformStatusMostRecentScaleType  \
#  0    ECOG 1 / Karnofsky 80-90%          ECOG Performance status
#  1    ECOG 1 / Karnofsky 80-90%          ECOG Performance status
#  2    ECOG 2 / Karnofsky 60-70%          ECOG Performance status
#  3      ECOG 0 / Karnofsky 100%          ECOG Performance status
#  4    ECOG 2 / Karnofsky 60-70%          ECOG Performance status
#  ..                         ...                              ...
#  176  ECOG 1 / Karnofsky 80-90%          ECOG Performance status
#  177  ECOG 2 / Karnofsky 60-70%          ECOG Performance status
#  178  ECOG 2 / Karnofsky 60-70%          ECOG Performance status
#  179  ECOG 3 / Karnofsky 40-50%          ECOG Performance status
#  180  ECOG 1 / Karnofsky 80-90%          ECOG Performance status
#
#      AgeAtCurrentDiseaseStatus   AgeAtCurrentDiseaseStatusFlag  \
#  0                      64.225  Age derived from complete date
#  1                      77.548  Age derived from complete date
#  2                      71.047  Age derived from complete date
#  3                      68.937  Age derived from complete date
#  4                      69.310  Age derived from complete date
#  ..                        ...                             ...
#  176                    58.751  Age derived from complete date
#  177                    75.447  Age derived from complete date
#  178                    68.014  Age derived from complete date
#  179                    77.778  Age derived from complete date
#  180                    70.882  Age derived from complete date
#
#      YearOfCurrentDiseaseStatus    CurrentDiseaseStatus
#  0                         2017  No Evidence of Disease
#  1                         2023          Active Disease
#  2                         2018          Active Disease
#  3                         2018          Active Disease
#  4                         2018          Active Disease
#  ..                         ...                     ...
#  176                       2023          Active Disease
#  177                       2022  No Evidence of Disease
#  178                       2021          Active Disease
#  179                       2021          Active Disease
#  180                       2022  No Evidence of Disease
#
#  [181 rows x 37 columns]}

# %%
df_dict['TumorMarkerFlowPanel']
# Out:
#      AvatarKey  TumorMarkerKey FlowPanelName FlowPanelResult
# 0      A006746          271432         CD117        Positive
# 1      A006746          271432          CD13        Positive
# 2      A006746          271432          CD33        Positive
# 3      A006746          271432          CD34        Positive
# 4      A006746          271432          CD45        Positive
# ...        ...             ...           ...             ...
# 1804   A040113          271451          CD34        Positive
# 1805   A040113          271451           CD4        Negative
# 1806   A040113          271451           CD5        Negative
# 1807   A040113          271451        HLA-DR        Positive
# 1808   A040114          271454          CD14        Positive
#
# [1809 rows x 4 columns]

# %% [markdown]
# ## Check which datasets have multiple rows per patient

# %%
for dataset in df_dict:
    current_df = df_dict[dataset]
    #AvatarKey column is the first columns
    print(str(dataset))
    j = (current_df[current_df.columns[0]])
    if (j.value_counts() > 1).any():
        print(True)
    else:
        print(False)
# Out:
# TumorMarkerFlowPanel
# True
# PhysicalAssessment
# False
# TumorMarker
# True
# CytogeneticAbnormalities
# True
# Diagnosis
# True
# VitalStatus
# False
# ClinicalMolLinkage
# False
# Medications
# True
# PatientMaster
# False
# PatientHistory
# False
# StemCellTransplant
# False
# Outcomes
# True

# %%
current_df
# Out:
#     AvatarKey OutcomesPrimaryDiagnosisSiteCode OutcomesPrimaryDiagnosisSite  \
# 0     A030981                            C42.1                  Bone marrow
# 1     A030982                            C42.1                  Bone marrow
# 2     A030983                            C42.1                  Bone marrow
# 3     A030984                            C42.1                  Bone marrow
# 4     A030985                            C42.1                  Bone marrow
# ..        ...                              ...                          ...
# 176   A040109                            C42.1                  Bone marrow
# 177   A040111                            C42.1                  Bone marrow
# 178   A040112                            C42.1                  Bone marrow
# 179   A040113                            C42.1                  Bone marrow
# 180   A040114                            C42.1                  Bone marrow
#
#                ProgRecurInd          AgeAtProgRecur  \
# 0    Unknown/Not Applicable  Unknown/Not Applicable
# 1               Progression                  74.995
# 2    Unknown/Not Applicable  Unknown/Not Applicable
# 3    Unknown/Not Applicable  Unknown/Not Applicable
# 4    Unknown/Not Applicable  Unknown/Not Applicable
# ..                      ...                     ...
# 176             Progression                  56.504
# 177  Unknown/Not Applicable  Unknown/Not Applicable
# 178  Unknown/Not Applicable  Unknown/Not Applicable
# 179  Unknown/Not Applicable  Unknown/Not Applicable
# 180  Unknown/Not Applicable  Unknown/Not Applicable
#
#                  AgeAtProgRecurFlag         YearOfProgRecur  \
# 0            Unknown/Not Applicable  Unknown/Not Applicable
# 1    Age derived from complete date                    2021
# 2            Unknown/Not Applicable  Unknown/Not Applicable
# 3            Unknown/Not Applicable  Unknown/Not Applicable
# 4            Unknown/Not Applicable  Unknown/Not Applicable
# ..                              ...                     ...
# 176  Age derived from complete date                    2020
# 177          Unknown/Not Applicable  Unknown/Not Applicable
# 178          Unknown/Not Applicable  Unknown/Not Applicable
# 179          Unknown/Not Applicable  Unknown/Not Applicable
# 180          Unknown/Not Applicable  Unknown/Not Applicable
#
#     ProgSourceFromTumorMarker ProgSourceFromImaging ProgSourceFromPathConfirm  \
# 0                          No                    No                        No
# 1                          No                    No                        No
# 2                          No                    No                        No
# 3                          No                    No                        No
# 4                          No                    No                        No
# ..                        ...                   ...                       ...
# 176                        No                    No                        No
# 177                        No                    No                        No
# 178                        No                    No                        No
# 179                        No                    No                        No
# 180                        No                    No                        No
#
#      ... BestRespFromClinicalRecord AgeAtPerformStatusMostRecent  \
# 0    ...                        Yes                       63.534
# 1    ...                        Yes                       77.315
# 2    ...                        Yes                       71.047
# 3    ...                        Yes                       68.814
# 4    ...                        Yes                       68.518
# ..   ...                        ...                          ...
# 176  ...                        Yes                       58.751
# 177  ...                        Yes                       75.447
# 178  ...                        Yes                       68.014
# 179  ...                        Yes                       77.800
# 180  ...                        Yes                       70.863
#
#     AgeAtPerformStatusMostRecentFlag YearOfPerformStatusMostRecent  \
# 0     Age derived from complete date                          2016
# 1     Age derived from complete date                          2023
# 2     Age derived from complete date                          2018
# 3     Age derived from complete date                          2018
# 4     Age derived from complete date                          2018
# ..                               ...                           ...
# 176   Age derived from complete date                          2023
# 177   Age derived from complete date                          2022
# 178   Age derived from complete date                          2021
# 179   Age derived from complete date                          2021
# 180   Age derived from complete date                          2022
#
#        PerformStatusMostRecent PerformStatusMostRecentScaleType  \
# 0    ECOG 1 / Karnofsky 80-90%          ECOG Performance status
# 1    ECOG 1 / Karnofsky 80-90%          ECOG Performance status
# 2    ECOG 2 / Karnofsky 60-70%          ECOG Performance status
# 3      ECOG 0 / Karnofsky 100%          ECOG Performance status
# 4    ECOG 2 / Karnofsky 60-70%          ECOG Performance status
# ..                         ...                              ...
# 176  ECOG 1 / Karnofsky 80-90%          ECOG Performance status
# 177  ECOG 2 / Karnofsky 60-70%          ECOG Performance status
# 178  ECOG 2 / Karnofsky 60-70%          ECOG Performance status
# 179  ECOG 3 / Karnofsky 40-50%          ECOG Performance status
# 180  ECOG 1 / Karnofsky 80-90%          ECOG Performance status
#
#     AgeAtCurrentDiseaseStatus   AgeAtCurrentDiseaseStatusFlag  \
# 0                      64.225  Age derived from complete date
# 1                      77.548  Age derived from complete date
# 2                      71.047  Age derived from complete date
# 3                      68.937  Age derived from complete date
# 4                      69.310  Age derived from complete date
# ..                        ...                             ...
# 176                    58.751  Age derived from complete date
# 177                    75.447  Age derived from complete date
# 178                    68.014  Age derived from complete date
# 179                    77.778  Age derived from complete date
# 180                    70.882  Age derived from complete date
#
#     YearOfCurrentDiseaseStatus    CurrentDiseaseStatus
# 0                         2017  No Evidence of Disease
# 1                         2023          Active Disease
# 2                         2018          Active Disease
# 3                         2018          Active Disease
# 4                         2018          Active Disease
# ..                         ...                     ...
# 176                       2023          Active Disease
# 177                       2022  No Evidence of Disease
# 178                       2021          Active Disease
# 179                       2021          Active Disease
# 180                       2022  No Evidence of Disease
#
# [181 rows x 37 columns]

# %% [markdown]
# ## Cleaning diagnosis data

# %%
diagnosis = df_dict['Diagnosis']
diagnosis
# Out:
#     AvatarKey AgeAtFirstContact           AgeAtFirstContactFlag  \
# 0     A006690            59.556  Age derived from complete date
# 1     A006690            59.556  Age derived from complete date
# 2     A039952            32.523  Age derived from complete date
# 3     A039953            50.332  Age derived from complete date
# 4     A039956            59.893  Age derived from complete date
# ..        ...               ...                             ...
# 157   A049229            58.622  Age derived from complete date
# 158   A049231            38.123  Age derived from complete date
# 159   A049233            66.233  Age derived from complete date
# 160   A049236            76.964  Age derived from complete date
# 161   A049237            60.093  Age derived from complete date
#
#      YearOfFirstContact AgeAtDiagnosis              AgeAtDiagnosisFlag  \
# 0                  2015         50.512  Age derived from complete date
# 1                  2015         59.474  Age derived from complete date
# 2                  2003         32.523  Age derived from complete date
# 3                  2016         50.332  Age derived from complete date
# 4                  2017         59.893  Age derived from complete date
# ..                  ...            ...                             ...
# 157                2019         58.622  Age derived from complete date
# 158                2020         38.123  Age derived from complete date
# 159                2021         66.233  Age derived from complete date
# 160                2021         76.964  Age derived from complete date
# 161                2020         60.093  Age derived from complete date
#
#      YearOfDiagnosis PrimaryDiagnosisSiteCode      PrimaryDiagnosisSite  \
# 0               2006                    C42.1               Bone marrow
# 1               2015                    C15.5  Lower third of esophagus
# 2               2003                    C42.1               Bone marrow
# 3               2016                    C42.1               Bone marrow
# 4               2017                    C42.1               Bone marrow
# ..               ...                      ...                       ...
# 157             2019                    C42.1               Bone marrow
# 158             2020                    C42.1               Bone marrow
# 159             2021                    C42.1               Bone marrow
# 160             2021                    C42.1               Bone marrow
# 161             2020                    C42.1               Bone marrow
#
#                      Laterality  ... AgeAtOtherStagingSystemFlag  \
# 0    Organ is not a paired site  ...    Age Unknown/Not Recorded
# 1    Organ is not a paired site  ...    Age Unknown/Not Recorded
# 2    Organ is not a paired site  ...    Age Unknown/Not Recorded
# 3    Organ is not a paired site  ...    Age Unknown/Not Recorded
# 4    Organ is not a paired site  ...    Age Unknown/Not Recorded
# ..                          ...  ...                         ...
# 157  Organ is not a paired site  ...    Age Unknown/Not Recorded
# 158  Organ is not a paired site  ...    Age Unknown/Not Recorded
# 159  Organ is not a paired site  ...    Age Unknown/Not Recorded
# 160  Organ is not a paired site  ...    Age Unknown/Not Recorded
# 161  Organ is not a paired site  ...    Age Unknown/Not Recorded
#
#      YearOfOtherStagingSystem      OtherStagingSystem       OtherStagingValue  \
# 0    Age Unknown/Not Recorded  Unknown/Not Applicable  Unknown/Not Applicable
# 1    Age Unknown/Not Recorded  Unknown/Not Applicable  Unknown/Not Applicable
# 2    Age Unknown/Not Recorded  Unknown/Not Applicable  Unknown/Not Applicable
# 3    Age Unknown/Not Recorded  Unknown/Not Applicable  Unknown/Not Applicable
# 4    Age Unknown/Not Recorded  Unknown/Not Applicable  Unknown/Not Applicable
# ..                        ...                     ...                     ...
# 157  Age Unknown/Not Recorded  Unknown/Not Applicable  Unknown/Not Applicable
# 158  Age Unknown/Not Recorded  Unknown/Not Applicable  Unknown/Not Applicable
# 159  Age Unknown/Not Recorded  Unknown/Not Applicable  Unknown/Not Applicable
# 160  Age Unknown/Not Recorded  Unknown/Not Applicable  Unknown/Not Applicable
# 161  Age Unknown/Not Recorded  Unknown/Not Applicable  Unknown/Not Applicable
#
#     CurrentlySeenForPrimaryOrRecurr AgeAtPerformanceStatusAtDiagnosis  \
# 0               Progressive Disease          Age Unknown/Not Recorded
# 1                 Primary Diagnosis          Age Unknown/Not Recorded
# 2                 Primary Diagnosis          Age Unknown/Not Recorded
# 3                 Primary Diagnosis          Age Unknown/Not Recorded
# 4                 Primary Diagnosis          Age Unknown/Not Recorded
# ..                              ...                               ...
# 157               Primary Diagnosis          Age Unknown/Not Recorded
# 158               Primary Diagnosis                            38.167
# 159               Primary Diagnosis          Age Unknown/Not Recorded
# 160               Primary Diagnosis                            77.003
# 161               Primary Diagnosis          Age Unknown/Not Recorded
#
#     AgeAtPerformanceStatusAtDiagnosisFlag YearOfPerformanceStatusAtDiagnosis  \
# 0                Age Unknown/Not Recorded           Age Unknown/Not Recorded
# 1                Age Unknown/Not Recorded           Age Unknown/Not Recorded
# 2                Age Unknown/Not Recorded           Age Unknown/Not Recorded
# 3                Age Unknown/Not Recorded           Age Unknown/Not Recorded
# 4                Age Unknown/Not Recorded           Age Unknown/Not Recorded
# ..                                    ...                                ...
# 157              Age Unknown/Not Recorded           Age Unknown/Not Recorded
# 158        Age derived from complete date                               2020
# 159              Age Unknown/Not Recorded           Age Unknown/Not Recorded
# 160        Age derived from complete date                               2021
# 161              Age Unknown/Not Recorded           Age Unknown/Not Recorded
#
#       PerformStatusAtDiagnosis PerformStatusAtDiagnosisScale
# 0        Unknown/Not Performed         Unknown/Not Performed
# 1        Unknown/Not Performed         Unknown/Not Performed
# 2        Unknown/Not Performed         Unknown/Not Performed
# 3        Unknown/Not Performed         Unknown/Not Performed
# 4        Unknown/Not Performed         Unknown/Not Performed
# ..                         ...                           ...
# 157      Unknown/Not Performed         Unknown/Not Performed
# 158  ECOG 2 / Karnofsky 60-70%       ECOG Performance status
# 159      Unknown/Not Performed         Unknown/Not Performed
# 160  ECOG 1 / Karnofsky 80-90%       ECOG Performance status
# 161      Unknown/Not Performed         Unknown/Not Performed
#
# [162 rows x 41 columns]

# %%
column_names = diagnosis.columns.tolist()
column_names
# Out:
# ['AvatarKey',
#  'AgeAtFirstContact',
#  'AgeAtFirstContactFlag',
#  'YearOfFirstContact',
#  'AgeAtDiagnosis',
#  'AgeAtDiagnosisFlag',
#  'YearOfDiagnosis',
#  'PrimaryDiagnosisSiteCode',
#  'PrimaryDiagnosisSite',
#  'Laterality',
#  'HistologyCode',
#  'Histology',
#  'GradeClinical',
#  'GradePathological',
#  'GradePostTherapy',
#  'HemMaligImmunophenotype',
#  'HemMaligPhase',
#  'ClinTStage',
#  'ClinNStage',
#  'ClinMStage',
#  'ClinGroupStage',
#  'PathTStage',
#  'PathNStage',
#  'PathMStage',
#  'PathGroupStage',
#  'TNMClassification_aTNM',
#  'TNMClassification_rTNM',
#  'TNMClassification_ycTNM',
#  'TNMClassification_ypTNM',
#  'TNMEditionNumber',
#  'AgeAtOtherStagingSystem',
#  'AgeAtOtherStagingSystemFlag',
#  'YearOfOtherStagingSystem',
#  'OtherStagingSystem',
#  'OtherStagingValue',
#  'CurrentlySeenForPrimaryOrRecurr',
#  'AgeAtPerformanceStatusAtDiagnosis',
#  'AgeAtPerformanceStatusAtDiagnosisFlag',
#  'YearOfPerformanceStatusAtDiagnosis',
#  'PerformStatusAtDiagnosis',
#  'PerformStatusAtDiagnosisScale']

# %%
columns_to_keep = ['AvatarKey',
                    'AgeAtFirstContact',
                    'AgeAtDiagnosis',
                    'HistologyCode',
                    'Histology',
                    'CurrentlySeenForPrimaryOrRecurr',]
diagnosis_cleaned =  diagnosis[columns_to_keep]
diagnosis_cleaned
# Out:
#     AvatarKey AgeAtFirstContact AgeAtDiagnosis HistologyCode  \
# 0     A006690            59.556         50.512        9823/3
# 1     A006690            59.556         59.474        8140/3
# 2     A039952            32.523         32.523        9840/3
# 3     A039953            50.332         50.332        9861/3
# 4     A039956            59.893         59.893        9811/3
# ..        ...               ...            ...           ...
# 157   A049229            58.622         58.622        9861/3
# 158   A049231            38.123         38.123        9837/3
# 159   A049233            66.233         66.233        9866/3
# 160   A049236            76.964         76.964        9811/3
# 161   A049237            60.093         60.093        9861/3
#
#                                              Histology  \
# 0    Chronic lymphocytic leukemia/small lymphocytic...
# 1                                  Adenocarcinoma, NOS
# 2                             Acute erythroid leukemia
# 3                          Acute myeloid leukemia, NOS
# 4               B lymphoblastic leukemia/lymphoma, NOS
# ..                                                 ...
# 157                        Acute myeloid leukemia, NOS
# 158                  T lymphoblastic leukemia/lymphoma
# 159  Acute promyelocytic leukemia, t(15;17)(q22;q11...
# 160             B lymphoblastic leukemia/lymphoma, NOS
# 161                        Acute myeloid leukemia, NOS
#
#     CurrentlySeenForPrimaryOrRecurr
# 0               Progressive Disease
# 1                 Primary Diagnosis
# 2                 Primary Diagnosis
# 3                 Primary Diagnosis
# 4                 Primary Diagnosis
# ..                              ...
# 157               Primary Diagnosis
# 158               Primary Diagnosis
# 159               Primary Diagnosis
# 160               Primary Diagnosis
# 161               Primary Diagnosis
#
# [162 rows x 6 columns]

# %%
cancer=['leuk', 'lymp','myelo']
diagnosis_cleaned2 = diagnosis_cleaned[diagnosis_cleaned.applymap(lambda x: any(substring in str(x) for substring in cancer)).any(axis=1)]

keycounts = diagnosis_cleaned['AvatarKey'].value_counts()
multiples = keycounts[keycounts > 1]
keys = multiples.index
keys
# Out:
# Index(['A028334', 'A006690', 'A039969', 'A031000', 'A029225', 'A030993',
#        'A008286', 'A029215', 'A006746', 'A039966', 'A049227', 'A049229',
#        'A039956'],
#       dtype='object', name='AvatarKey')

# %%
diagnosis_cleaned['Histology'].unique()
# Out:
# array(['Chronic lymphocytic leukemia/small lymphocytic lymphoma',
#        'Adenocarcinoma, NOS', 'Acute erythroid leukemia',
#        'Acute myeloid leukemia, NOS',
#        'B lymphoblastic leukemia/lymphoma, NOS',
#        'T-cell large granular lymphocytic leukemia',
#        'Acute myeloid leukemia with multilineage dysplasia',
#        'Invasive carcinoma of no special type',
#        'Acute promyelocytic leukemia, t(15;17)(q22;q11-12)',
#        'Diffuse large B-cell lymphoma, NOS',
#        'Acute myelomonocytic leukemia', 'Myelodysplastic syndrome, NOS',
#        'Precursor cell lymphoblastic leukemia, NOS',
#        'Squamous cell carcinoma, NOS', 'Chronic myeloid leukemia, NOS',
#        'Chronic myelogenous leukemia, BCR/ABL positive',
#        'Therapy-related myeloid neoplasm',
#        'Prolymphocytic leukemia, T-cell type',
#        'Acute myeloid leukemia without maturation',
#        'Papillary transitional cell carcinoma, non-invasive',
#        'Acute myeloid leukemia with abnormal marrow eosinophils',
#        'Lobular carcinoma, NOS',
#        'Mantle cell lymphoma (includes all variants: blastic, pleomorphic, small cell)',
#        'Myelodysplastic syndrome with multilineage dysplasia',
#        'T lymphoblastic leukemia/lymphoma'], dtype=object)

# %%
inspect = diagnosis_cleaned[diagnosis_cleaned['AvatarKey'].isin(multiples.index)]
inspect
# Out:
#     AvatarKey AgeAtFirstContact AgeAtDiagnosis HistologyCode  \
# 0     A006690            59.556         50.512        9823/3
# 1     A006690            59.556         59.474        8140/3
# 4     A039956            59.893         59.893        9811/3
# 5     A039956            63.710         63.710        8140/3
# 10    A039966            63.189         63.038        8500/3
# 11    A039966            66.430         66.430        9861/3
# 14    A039969            58.142         58.142        9823/3
# 15    A039969            58.170         58.170        9680/3
# 39    A006746            79.899         79.112        9989/3
# 40    A006746            79.899         79.899        9895/3
# 53    A008286            67.030         67.036        9861/3
# 54    A008286            68.282         68.282        8070/3
# 84    A028334            73.910         73.910        8500/3
# 85    A028334            79.318         79.318        9823/3
# 86    A028334            83.564         81.129        8130/2
# 87    A028334            84.578         68.559        8140/3
# 88    A028334            84.578         84.578        8140/3
# 94    A029215            34.173         34.173        9823/3
# 95    A029215            40.137         40.137        8520/3
# 103   A029225            63.326         63.326        9823/3
# 104   A029225            63.326         63.326        9673/3
# 128   A030993            84.285         80.710        8140/3
# 129   A030993            84.285         84.285        9861/3
# 135   A031000            58.049         58.049        9989/3
# 136   A031000            59.197         59.197        9861/3
# 154   A049227            72.940         72.879        9989/3
# 155   A049227            76.795         76.795        9861/3
# 156   A049229            50.997         50.463        9823/3
# 157   A049229            58.622         58.622        9861/3
#
#                                              Histology  \
# 0    Chronic lymphocytic leukemia/small lymphocytic...
# 1                                  Adenocarcinoma, NOS
# 4               B lymphoblastic leukemia/lymphoma, NOS
# 5                                  Adenocarcinoma, NOS
# 10               Invasive carcinoma of no special type
# 11                         Acute myeloid leukemia, NOS
# 14   Chronic lymphocytic leukemia/small lymphocytic...
# 15                  Diffuse large B-cell lymphoma, NOS
# 39                       Myelodysplastic syndrome, NOS
# 40   Acute myeloid leukemia with multilineage dyspl...
# 53                         Acute myeloid leukemia, NOS
# 54                        Squamous cell carcinoma, NOS
# 84               Invasive carcinoma of no special type
# 85   Chronic lymphocytic leukemia/small lymphocytic...
# 86   Papillary transitional cell carcinoma, non-inv...
# 87                                 Adenocarcinoma, NOS
# 88                                 Adenocarcinoma, NOS
# 94   Chronic lymphocytic leukemia/small lymphocytic...
# 95                              Lobular carcinoma, NOS
# 103  Chronic lymphocytic leukemia/small lymphocytic...
# 104  Mantle cell lymphoma (includes all variants: b...
# 128                                Adenocarcinoma, NOS
# 129                        Acute myeloid leukemia, NOS
# 135                      Myelodysplastic syndrome, NOS
# 136                        Acute myeloid leukemia, NOS
# 154                      Myelodysplastic syndrome, NOS
# 155                        Acute myeloid leukemia, NOS
# 156  Chronic lymphocytic leukemia/small lymphocytic...
# 157                        Acute myeloid leukemia, NOS
#
#     CurrentlySeenForPrimaryOrRecurr
# 0               Progressive Disease
# 1                 Primary Diagnosis
# 4                 Primary Diagnosis
# 5                 Primary Diagnosis
# 10                Primary Diagnosis
# 11                Primary Diagnosis
# 14                Primary Diagnosis
# 15                Primary Diagnosis
# 39              Progressive Disease
# 40                Primary Diagnosis
# 53                Primary Diagnosis
# 54                Primary Diagnosis
# 84                Primary Diagnosis
# 85                Primary Diagnosis
# 86                Primary Diagnosis
# 87                Primary Diagnosis
# 88                Primary Diagnosis
# 94                Primary Diagnosis
# 95                Primary Diagnosis
# 103               Primary Diagnosis
# 104               Primary Diagnosis
# 128               Primary Diagnosis
# 129               Primary Diagnosis
# 135               Primary Diagnosis
# 136               Primary Diagnosis
# 154               Primary Diagnosis
# 155               Primary Diagnosis
# 156               Primary Diagnosis
# 157               Primary Diagnosis

# %%
inspect = flattened_df[flattened_df['AvatarKey'].isin(multiples.index)]
inspect
# Out:
#     AvatarKey AgeAtFirstContact AgeAtDiagnosis   HistologyCode  \
# 45    A029225            63.326         63.326  9823/3, 9673/3
# 102   A039969            58.156         58.156  9823/3, 9680/3
# 130   A049229            58.622         58.622          9861/3
#
#                                              Histology  \
# 45   Chronic lymphocytic leukemia/small lymphocytic...
# 102  Chronic lymphocytic leukemia/small lymphocytic...
# 130                        Acute myeloid leukemia, NOS
#
#     CurrentlySeenForPrimaryOrRecurr
# 45                Primary Diagnosis
# 102               Primary Diagnosis
# 130               Primary Diagnosis

# %%
flattened_df = diagnosis_cleaned.groupby('AvatarKey').agg(lambda x: ', '.join(map(str, x.unique()))).reset_index()

# %%
diagnosis_cleaned= diagnosis_cleaned.drop(index=156)

# %%
age_mapping = pd.read_csv('/standard/BDShackathon/teams/cherry_garcia/cleaned_clinical_data_csvs/age_mapping.csv')
age_mapping
# Out:
#     AvatarKey Age At Specimen Collection
# 0     A039956                     60.550
# 1     A039970                     47.930
# 2     A039973                     67.630
# 3     A039977                     55.300
# 4     A049227                     76.900
# ..        ...                        ...
# 141   A049250                     60.460
# 142   A039962                     67.540
# 143   A039980                     39.420
# 144   A040093                     65.380
# 145   A040096                     21.850
#
# [146 rows x 2 columns]

# %%
flattened_df.replace('58.142, 58.170', 58.156,inplace=True)

# %%
flattened_df
# Out:
#     AvatarKey AgeAtFirstContact AgeAtDiagnosis HistologyCode  \
# 0     A006690            59.556         50.512        9823/3
# 1     A006745            76.866         76.855        9867/3
# 2     A006746            79.899         79.899        9895/3
# 3     A006747            39.871         38.753        9861/3
# 4     A006748            52.581         52.581        9861/3
# ..        ...               ...            ...           ...
# 140   A049246            52.767         52.767        9861/3
# 141   A049247            79.921         79.921        9861/3
# 142   A049248            73.082         73.082        9861/3
# 143   A049250            60.463         60.463        9861/3
# 144   A049252            56.995         56.995        9861/3
#
#                                              Histology  \
# 0    Chronic lymphocytic leukemia/small lymphocytic...
# 1                        Acute myelomonocytic leukemia
# 2    Acute myeloid leukemia with multilineage dyspl...
# 3                          Acute myeloid leukemia, NOS
# 4                          Acute myeloid leukemia, NOS
# ..                                                 ...
# 140                        Acute myeloid leukemia, NOS
# 141                        Acute myeloid leukemia, NOS
# 142                        Acute myeloid leukemia, NOS
# 143                        Acute myeloid leukemia, NOS
# 144                        Acute myeloid leukemia, NOS
#
#     CurrentlySeenForPrimaryOrRecurr
# 0               Progressive Disease
# 1                 Primary Diagnosis
# 2                 Primary Diagnosis
# 3               Progressive Disease
# 4                 Primary Diagnosis
# ..                              ...
# 140               Primary Diagnosis
# 141               Primary Diagnosis
# 142               Primary Diagnosis
# 143               Primary Diagnosis
# 144               Primary Diagnosis
#
# [145 rows x 6 columns]

# %%
cancer=['leuk', 'lymp','myelo']


    
# Subset the DataFrame
subset_df = diagnosis_cleaned[diagnosis_cleaned.applymap(lambda x: any(substring in str(x) for substring in cancer)).any(axis=1)]

# Display the subset DataFrame
keycounts = subset_df['AvatarKey'].value_counts()
multiples = keycounts[keycounts > 1]

inspect = subset_df[subset_df['AvatarKey'].isin(multiples.index)]
inspect
# Out:
#     AvatarKey AgeAtFirstContact AgeAtDiagnosis HistologyCode  \
# 14    A039969            58.142         58.142        9823/3
# 15    A039969            58.170         58.170        9680/3
# 103   A029225            63.326         63.326        9823/3
# 104   A029225            63.326         63.326        9673/3
# 156   A049229            50.997         50.463        9823/3
# 157   A049229            58.622         58.622        9861/3
#
#                                              Histology  \
# 14   Chronic lymphocytic leukemia/small lymphocytic...
# 15                  Diffuse large B-cell lymphoma, NOS
# 103  Chronic lymphocytic leukemia/small lymphocytic...
# 104  Mantle cell lymphoma (includes all variants: b...
# 156  Chronic lymphocytic leukemia/small lymphocytic...
# 157                        Acute myeloid leukemia, NOS
#
#     CurrentlySeenForPrimaryOrRecurr
# 14                Primary Diagnosis
# 15                Primary Diagnosis
# 103               Primary Diagnosis
# 104               Primary Diagnosis
# 156               Primary Diagnosis
# 157               Primary Diagnosis

# %%
inspect =  flattened_df[flattened_df['AvatarKey'].isin(multiples.index)]
inspect
# Out:
#     AvatarKey AgeAtFirstContact AgeAtDiagnosis   HistologyCode  \
# 45    A029225            63.326         63.326  9823/3, 9673/3
# 102   A039969            58.156         58.156  9823/3, 9680/3
# 130   A049229            58.622         58.622          9861/3
#
#                                              Histology  \
# 45   Chronic lymphocytic leukemia/small lymphocytic...
# 102  Chronic lymphocytic leukemia/small lymphocytic...
# 130                        Acute myeloid leukemia, NOS
#
#     CurrentlySeenForPrimaryOrRecurr
# 45                Primary Diagnosis
# 102               Primary Diagnosis
# 130               Primary Diagnosis

# %%
cml = pd.read_csv('/standard/BDShackathon/teams/cherry_garcia/cleaned_clinical_data_csvs/CML_PH_PM_SCT_VS.csv')

# %%
cml.columns
# Out:
# Index(['AvatarKey', 'Site', 'Tumor/Germline', 'WES', 'WES Batch', 'RNASeq',
#        'RNA Batch', 'DiseaseType', 'SpecimenSiteOfOrigin',
#        'SpecimenSiteOfCollection', 'Primary/Met', 'SpecimenType',
#        'SpecimenDerivativeSource', 'Histology/Behavior', 'PreservationMethod',
#        '% Tumor Content', 'Age At Specimen Collection',
#        'SpecimenSiteOfOriginRollUp', 'SampleAgeInDays', 'ORIENSpecimenID',
#        'AgeAtLastUpdate', 'YearOfLastUpdate', 'SmokingStatus', 'AlcoholUse',
#        'AnemiaDiagnosisInd', 'COPDDiagnosisInd', 'CVAStrokeDiagnosisInd',
#        'DVTDiagnosisInd', 'GerdDiagnosisInd',
#        'HypercholesterolemiaDiagnosisInd', 'HyperlipidemiaDiagnosisInd',
#        'HypertensionDiagnosisInd', 'HypothyroidismDiagnosisInd',
#        'InsulinDependentDiabetesMellitusDiagnosisInd',
#        'HeartDiseaseDiagnosisInd', 'OsteoarthritisDiagnosisInd',
#        'PainDiagnosisInd', 'PulmonaryEmbolismDiagnosisInd',
#        'NoDrugToxicityInd', 'AgeAtOrganTransplant', 'AgeAtOrganTransplantFlag',
#        'YearOfOrganTransplant', 'OrganTransplantSite',
#        'AgeAtClinicalRecordCreation', 'YearOfClinicalRecordCreation', 'Sex',
#        'Race', 'Ethnicity', 'SCTInd', 'SCTPrimaryDiagnosisSiteCode',
#        'SCTPrimaryDiagnosisSite', 'AgeAtTransplant', 'AgeAtTransplantFlag',
#        'YearOfTransplant', 'TransplantType', 'TransplantCellSource',
#        'AgeAtPostTransStatus', 'AgeAtPostTransStatusFlag',
#        'YearOfPostTransStatus', 'MRDTestInd', 'AgeAtMRDTest',
#        'AgeAtMRDTestFlag', 'YearOfMRDTest', 'VitalStatus', 'AgeAtLastContact',
#        'AgeAtLastContactFlag', 'YearOfLastContact', 'AgeAtDeath',
#        'AgeAtDeathFlag', 'YearOfDeath', 'CauseOfDeath', 'VitalStatusConfirmed',
#        'VitalStatusSource'],
#       dtype='object')

# %%
am_keys= age_mapping['AvatarKey']
diag_keys = flattened_df['AvatarKey']

# Find values in list1 but not in list2
difference1 = list(set(am_keys) - set(diag_keys))

# Find values in list2 but not in list1
difference2 = list(set(diag_keys) - set(am_keys))

# Display the differences
print("In am but not in diag:", difference1)
print("In diag but not in am:", difference2)
# Out:
# In am but not in diag: ['A030984']
# In diag but not in am: []

# %%
diagnosis
# Out:
#     AvatarKey AgeAtFirstContact           AgeAtFirstContactFlag  \
# 0     A006690            59.556  Age derived from complete date
# 1     A006690            59.556  Age derived from complete date
# 2     A039952            32.523  Age derived from complete date
# 3     A039953            50.332  Age derived from complete date
# 4     A039956            59.893  Age derived from complete date
# ..        ...               ...                             ...
# 157   A049229            58.622  Age derived from complete date
# 158   A049231            38.123  Age derived from complete date
# 159   A049233            66.233  Age derived from complete date
# 160   A049236            76.964  Age derived from complete date
# 161   A049237            60.093  Age derived from complete date
#
#      YearOfFirstContact AgeAtDiagnosis              AgeAtDiagnosisFlag  \
# 0                  2015         50.512  Age derived from complete date
# 1                  2015         59.474  Age derived from complete date
# 2                  2003         32.523  Age derived from complete date
# 3                  2016         50.332  Age derived from complete date
# 4                  2017         59.893  Age derived from complete date
# ..                  ...            ...                             ...
# 157                2019         58.622  Age derived from complete date
# 158                2020         38.123  Age derived from complete date
# 159                2021         66.233  Age derived from complete date
# 160                2021         76.964  Age derived from complete date
# 161                2020         60.093  Age derived from complete date
#
#      YearOfDiagnosis PrimaryDiagnosisSiteCode      PrimaryDiagnosisSite  \
# 0               2006                    C42.1               Bone marrow
# 1               2015                    C15.5  Lower third of esophagus
# 2               2003                    C42.1               Bone marrow
# 3               2016                    C42.1               Bone marrow
# 4               2017                    C42.1               Bone marrow
# ..               ...                      ...                       ...
# 157             2019                    C42.1               Bone marrow
# 158             2020                    C42.1               Bone marrow
# 159             2021                    C42.1               Bone marrow
# 160             2021                    C42.1               Bone marrow
# 161             2020                    C42.1               Bone marrow
#
#                      Laterality  ... AgeAtOtherStagingSystemFlag  \
# 0    Organ is not a paired site  ...    Age Unknown/Not Recorded
# 1    Organ is not a paired site  ...    Age Unknown/Not Recorded
# 2    Organ is not a paired site  ...    Age Unknown/Not Recorded
# 3    Organ is not a paired site  ...    Age Unknown/Not Recorded
# 4    Organ is not a paired site  ...    Age Unknown/Not Recorded
# ..                          ...  ...                         ...
# 157  Organ is not a paired site  ...    Age Unknown/Not Recorded
# 158  Organ is not a paired site  ...    Age Unknown/Not Recorded
# 159  Organ is not a paired site  ...    Age Unknown/Not Recorded
# 160  Organ is not a paired site  ...    Age Unknown/Not Recorded
# 161  Organ is not a paired site  ...    Age Unknown/Not Recorded
#
#      YearOfOtherStagingSystem      OtherStagingSystem       OtherStagingValue  \
# 0    Age Unknown/Not Recorded  Unknown/Not Applicable  Unknown/Not Applicable
# 1    Age Unknown/Not Recorded  Unknown/Not Applicable  Unknown/Not Applicable
# 2    Age Unknown/Not Recorded  Unknown/Not Applicable  Unknown/Not Applicable
# 3    Age Unknown/Not Recorded  Unknown/Not Applicable  Unknown/Not Applicable
# 4    Age Unknown/Not Recorded  Unknown/Not Applicable  Unknown/Not Applicable
# ..                        ...                     ...                     ...
# 157  Age Unknown/Not Recorded  Unknown/Not Applicable  Unknown/Not Applicable
# 158  Age Unknown/Not Recorded  Unknown/Not Applicable  Unknown/Not Applicable
# 159  Age Unknown/Not Recorded  Unknown/Not Applicable  Unknown/Not Applicable
# 160  Age Unknown/Not Recorded  Unknown/Not Applicable  Unknown/Not Applicable
# 161  Age Unknown/Not Recorded  Unknown/Not Applicable  Unknown/Not Applicable
#
#     CurrentlySeenForPrimaryOrRecurr AgeAtPerformanceStatusAtDiagnosis  \
# 0               Progressive Disease          Age Unknown/Not Recorded
# 1                 Primary Diagnosis          Age Unknown/Not Recorded
# 2                 Primary Diagnosis          Age Unknown/Not Recorded
# 3                 Primary Diagnosis          Age Unknown/Not Recorded
# 4                 Primary Diagnosis          Age Unknown/Not Recorded
# ..                              ...                               ...
# 157               Primary Diagnosis          Age Unknown/Not Recorded
# 158               Primary Diagnosis                            38.167
# 159               Primary Diagnosis          Age Unknown/Not Recorded
# 160               Primary Diagnosis                            77.003
# 161               Primary Diagnosis          Age Unknown/Not Recorded
#
#     AgeAtPerformanceStatusAtDiagnosisFlag YearOfPerformanceStatusAtDiagnosis  \
# 0                Age Unknown/Not Recorded           Age Unknown/Not Recorded
# 1                Age Unknown/Not Recorded           Age Unknown/Not Recorded
# 2                Age Unknown/Not Recorded           Age Unknown/Not Recorded
# 3                Age Unknown/Not Recorded           Age Unknown/Not Recorded
# 4                Age Unknown/Not Recorded           Age Unknown/Not Recorded
# ..                                    ...                                ...
# 157              Age Unknown/Not Recorded           Age Unknown/Not Recorded
# 158        Age derived from complete date                               2020
# 159              Age Unknown/Not Recorded           Age Unknown/Not Recorded
# 160        Age derived from complete date                               2021
# 161              Age Unknown/Not Recorded           Age Unknown/Not Recorded
#
#       PerformStatusAtDiagnosis PerformStatusAtDiagnosisScale
# 0        Unknown/Not Performed         Unknown/Not Performed
# 1        Unknown/Not Performed         Unknown/Not Performed
# 2        Unknown/Not Performed         Unknown/Not Performed
# 3        Unknown/Not Performed         Unknown/Not Performed
# 4        Unknown/Not Performed         Unknown/Not Performed
# ..                         ...                           ...
# 157      Unknown/Not Performed         Unknown/Not Performed
# 158  ECOG 2 / Karnofsky 60-70%       ECOG Performance status
# 159      Unknown/Not Performed         Unknown/Not Performed
# 160  ECOG 1 / Karnofsky 80-90%       ECOG Performance status
# 161      Unknown/Not Performed         Unknown/Not Performed
#
# [162 rows x 41 columns]

# %%
diagnosis = df_dict['Diagnosis']


columns_to_keep = ['AvatarKey',
                    'AgeAtFirstContact',
                    'AgeAtDiagnosis',
                    'HistologyCode',
                    'Histology',
                    'CurrentlySeenForPrimaryOrRecurr',]



diagnosis_cleaned =  diagnosis[columns_to_keep]
diagnosis_cleaned

diagnosis.to_csv('/standard/BDShackathon/teams/cherry_garcia/cleaned_clinical_data_csvs/diagnosis_v2.csv')

# %%
#cancer=['leuk', 'lymp','myel']
#diagnosis_cleaned2 = diagnosis_cleaned[diagnosis_cleaned.applymap(lambda x: any(substring in str(x) for substring in cancer)).any(axis=1)]
diagnosis.to_csv('/standard/BDShackathon/teams/cherry_garcia/cleaned_clinical_data_csvs/diagnosis_v2.csv')

# %%
row_to_add = diagnosis_cleaned.iloc[119]
row_to_add
# Out:
# AvatarKey                                                                    A030984
# AgeAtFirstContact                                                             68.482
# AgeAtDiagnosis                                                                68.482
# HistologyCode                                                                 9985/3
# Histology                          Myelodysplastic syndrome with multilineage dys...
# CurrentlySeenForPrimaryOrRecurr                                    Primary Diagnosis
# Name: 119, dtype: object

# %%
flattened_df2 = pd.concat([flattened_df, pd.DataFrame([row_to_add])], ignore_index=True)

# %%
flattened_df2.to_csv('/standard/BDShackathon/teams/cherry_garcia/cleaned_clinical_data_csvs/diagnosis.csv')

# %%
diagnosis = pd.read_csv('/standard/BDShackathon/teams/cherry_garcia/cleaned_clinical_data_csvs/diagnosis.csv')

# %%
len(diagnosis['Histology'].unique())
diagnosis['Histology'].unique()
# Out:
# array(['Chronic lymphocytic leukemia/small lymphocytic lymphoma',
#        'Acute myelomonocytic leukemia',
#        'Acute myeloid leukemia with multilineage dysplasia',
#        'Acute myeloid leukemia, NOS',
#        'Precursor cell lymphoblastic leukemia, NOS',
#        'Chronic myeloid leukemia, NOS',
#        'T-cell large granular lymphocytic leukemia',
#        'Acute myeloid leukemia without maturation',
#        'Acute myeloid leukemia with abnormal marrow eosinophils',
#        'Chronic lymphocytic leukemia/small lymphocytic lymphoma, Mantle cell lymphoma (includes all variants: blastic, pleomorphic, small cell)',
#        'B lymphoblastic leukemia/lymphoma, NOS',
#        'Acute erythroid leukemia',
#        'Acute promyelocytic leukemia, t(15;17)(q22;q11-12)',
#        'Chronic lymphocytic leukemia/small lymphocytic lymphoma, Diffuse large B-cell lymphoma, NOS',
#        'Chronic myelogenous leukemia, BCR/ABL positive',
#        'Therapy-related myeloid neoplasm',
#        'Prolymphocytic leukemia, T-cell type',
#        'T lymphoblastic leukemia/lymphoma',
#        'Myelodysplastic syndrome with multilineage dysplasia'],
#       dtype=object)

# %%
diagnosis['Histology'].value_counts()
# Out:
# Histology
# Acute myeloid leukemia                                     61
# Chronic lymphocytic leukemia/small lymphocytic lymphoma    49
# B lymphoblastic leukemia/lymphoma                           9
# Chronic myeloid leukemia                                    7
# Other                                                       7
# T-cell large granular lymphocytic leukemia                  6
# Acute promyelocytic leukemia                                3
# Acute myelomonocytic leukemia                               2
# Precursor cell lymphoblastic leukemia                       2
# Name: count, dtype: int64

# %%
diagnosis
# Out:
#      Unnamed: 0 AvatarKey AgeAtFirstContact AgeAtDiagnosis HistologyCode  \
# 0             0   A006690            59.556         50.512        9823/3
# 1             1   A006745            76.866         76.855        9867/3
# 2             2   A006746            79.899         79.899        9895/3
# 3             3   A006747            39.871         38.753        9861/3
# 4             4   A006748            52.581         52.581        9861/3
# ..          ...       ...               ...            ...           ...
# 141         141   A049247            79.921         79.921        9861/3
# 142         142   A049248            73.082         73.082        9861/3
# 143         143   A049250            60.463         60.463        9861/3
# 144         144   A049252            56.995         56.995        9861/3
# 145         145   A030984            68.482         68.482        9985/3
#
#                                              Histology  \
# 0    Chronic lymphocytic leukemia/small lymphocytic...
# 1                        Acute myelomonocytic leukemia
# 2                               Acute myeloid leukemia
# 3                               Acute myeloid leukemia
# 4                               Acute myeloid leukemia
# ..                                                 ...
# 141                             Acute myeloid leukemia
# 142                             Acute myeloid leukemia
# 143                             Acute myeloid leukemia
# 144                             Acute myeloid leukemia
# 145                                              Other
#
#     CurrentlySeenForPrimaryOrRecurr
# 0               Progressive Disease
# 1                 Primary Diagnosis
# 2                 Primary Diagnosis
# 3               Progressive Disease
# 4                 Primary Diagnosis
# ..                              ...
# 141               Primary Diagnosis
# 142               Primary Diagnosis
# 143               Primary Diagnosis
# 144               Primary Diagnosis
# 145               Primary Diagnosis
#
# [146 rows x 7 columns]

# %%
diagnosis['HistologyCode'].unique()
# Out:
# array(['9823/3', '9867/3', '9895/3', '9861/3', '9835/3', '9863/3',
#        '9831/3', '9873/3', '9871/3', '9823/3, 9673/3', '9811/3', '9840/3',
#        '9866/3', '9823/3, 9680/3', '9875/3', '9920/3', '9834/3', '9837/3',
#        '9985/3'], dtype=object)

# %%
diagnosis.replace('Acute promyelocytic leukemia, t(15;17)(q22;q11-12)','Acute promyelocytic leukemia',inplace=True)

# %%
subtype_counts = diagnosis['Histology'].value_counts().reset_index()
subtype_counts.columns =['Subtype','Count']
subtype_counts_below_1p= subtype_counts[subtype_counts['Count']<2]
subtype_counts_below_1p
# Out:
# Empty DataFrame
# Columns: [Subtype, Count]
# Index: []

# %%
for i in subtype_counts_below_1p['Subtype']:
    print(i)
    diagnosis.replace(i,'Other',inplace=True)
# Out:
# Chronic lymphocytic leukemia/small lymphocytic lymphoma, Mantle cell lymphoma (includes all variants: blastic, pleomorphic, small cell)
# Acute erythroid leukemia
# Chronic lymphocytic leukemia/small lymphocytic lymphoma, Diffuse large B-cell lymphoma, NOS
# Therapy-related myeloid neoplasm
# Prolymphocytic leukemia, T-cell type
# T lymphoblastic leukemia/lymphoma
# Myelodysplastic syndrome with multilineage dysplasia

# %%
plt.figure(figsize=(6, 6))
plt.barh(subtype_counts['Subtype'], subtype_counts['Count'], color='skyblue')
plt.xlabel('Count')
plt.ylabel('Clinical Subtypes (Histology)')
plt.title('Distribution of Clinical Subtypes')
plt.show()

# %%
diagnosis.to_csv('/standard/BDShackathon/teams/cherry_garcia/cleaned_clinical_data_csvs/diagnosis_v2.csv',index=False)

# %%
#diagnosis = diagnosis.iloc[:, 2:]
diagnosis = pd.read_csv('/standard/BDShackathon/teams/cherry_garcia/cleaned_clinical_data_csvs/diagnosis_v2.csv')

# %%
histology = diagnosis[['AvatarKey','Histology']]
histology
# Out:
#     AvatarKey                                          Histology
# 0     A006690  Chronic lymphocytic leukemia/small lymphocytic...
# 1     A006745                      Acute myelomonocytic leukemia
# 2     A006746                             Acute myeloid leukemia
# 3     A006747                             Acute myeloid leukemia
# 4     A006748                             Acute myeloid leukemia
# ..        ...                                                ...
# 141   A049247                             Acute myeloid leukemia
# 142   A049248                             Acute myeloid leukemia
# 143   A049250                             Acute myeloid leukemia
# 144   A049252                             Acute myeloid leukemia
# 145   A030984                                              Other
#
# [146 rows x 2 columns]

# %%
umap=pd.read_csv('/standard/BDShackathon/teams/cherry_garcia/rnaseq-umap.csv')
umap.columns = ['AvatarKey','UMAP1','UMAP2']
umap
# Out:
#     AvatarKey     UMAP1     UMAP2
# 0     A039956  1.931204  4.815634
# 1     A039970  1.475605  5.174460
# 2     A039973  1.331029  3.595758
# 3     A039977  1.157723  4.683093
# 4     A049227 -1.352426  2.897019
# ..        ...       ...       ...
# 139   A049250 -0.356274  3.831278
# 140   A039962 -0.832108  3.986470
# 141   A039980  0.271424  4.392237
# 142   A040093 -1.276125  3.642198
# 143   A040096 -1.259416  3.827409
#
# [144 rows x 3 columns]

# %%
umap_merged = pd.merge(umap, histology, on='AvatarKey')
umap_merged
# Out:
#     AvatarKey     UMAP1     UMAP2  \
# 0     A039956  1.931204  4.815634
# 1     A039970  1.475605  5.174460
# 2     A039973  1.331029  3.595758
# 3     A039977  1.157723  4.683093
# 4     A049227 -1.352426  2.897019
# ..        ...       ...       ...
# 139   A049250 -0.356274  3.831278
# 140   A039962 -0.832108  3.986470
# 141   A039980  0.271424  4.392237
# 142   A040093 -1.276125  3.642198
# 143   A040096 -1.259416  3.827409
#
#                                              Histology
# 0                    B lymphoblastic leukemia/lymphoma
# 1                               Acute myeloid leukemia
# 2    Chronic lymphocytic leukemia/small lymphocytic...
# 3                               Acute myeloid leukemia
# 4                               Acute myeloid leukemia
# ..                                                 ...
# 139                             Acute myeloid leukemia
# 140                             Acute myeloid leukemia
# 141                       Acute promyelocytic leukemia
# 142  Chronic lymphocytic leukemia/small lymphocytic...
# 143                           Chronic myeloid leukemia
#
# [144 rows x 4 columns]

# %%
plt.figure(figsize=(12,5))
sns.scatterplot(
            x=umap_merged['UMAP1'],
            y=umap_merged['UMAP2'],
            hue=umap_merged['Histology'],
            palette= 'tab10',
            data=umap_merged
        )

plt.legend(bbox_to_anchor=(1.1 ,0.5), loc='center left', borderaxespad=0.)
plt.tight_layout()
plt.show()
#plt.xlabel("UMAP-1")
#plt.ylabel("UMAP-2")

# %%
outcomes = df_dict['Outcomes']
outcomes.columns

outcomes = outcomes[['AvatarKey',
                    'ProgRecurInd','RecurrenceType', 'RelapseStatus',
                    'DiseaseGroupBestResp', 'AMLResponse', 'CMLResponse', 'CLLResponse',
       'MDSResponse', 'JMMLResponse', 'MultipleMyelomaPCLResponse','CurrentDiseaseStatus']]
outcomes
# Out:
#     AvatarKey            ProgRecurInd          RecurrenceType  \
# 0     A030981  Unknown/Not Applicable  Unknown/Not Applicable
# 1     A030982             Progression  Unknown/Not Applicable
# 2     A030983  Unknown/Not Applicable  Unknown/Not Applicable
# 3     A030984  Unknown/Not Applicable  Unknown/Not Applicable
# 4     A030985  Unknown/Not Applicable  Unknown/Not Applicable
# ..        ...                     ...                     ...
# 176   A040109             Progression  Unknown/Not Applicable
# 177   A040111  Unknown/Not Applicable  Unknown/Not Applicable
# 178   A040112  Unknown/Not Applicable  Unknown/Not Applicable
# 179   A040113  Unknown/Not Applicable  Unknown/Not Applicable
# 180   A040114  Unknown/Not Applicable  Unknown/Not Applicable
#
#               RelapseStatus DiseaseGroupBestResp  \
# 0    Unknown/Not Applicable                  AML
# 1    Unknown/Not Applicable                  CLL
# 2    Unknown/Not Applicable                  AML
# 3    Unknown/Not Applicable                  MDS
# 4    Unknown/Not Applicable                  AML
# ..                      ...                  ...
# 176  Unknown/Not Applicable                  CML
# 177  Unknown/Not Applicable                  AML
# 178  Unknown/Not Applicable                  CLL
# 179  Unknown/Not Applicable                  AML
# 180  Unknown/Not Applicable                  AML
#
#                                            AMLResponse  \
# 0                     Complete Response/Remission (CR)
# 1                               Unknown/Not Applicable
# 2                                 Not Assessed/Unknown
# 3                               Unknown/Not Applicable
# 4                                 Not Assessed/Unknown
# ..                                                 ...
# 176                             Unknown/Not Applicable
# 177                   Complete Response/Remission (CR)
# 178                             Unknown/Not Applicable
# 179                                          Untreated
# 180  Complete Response with Incomplete Hematologic ...
#
#                 CMLResponse                           CLLResponse  \
# 0    Unknown/Not Applicable                Unknown/Not Applicable
# 1    Unknown/Not Applicable  No Response (NR)/Stable Disease (SD)
# 2    Unknown/Not Applicable                Unknown/Not Applicable
# 3    Unknown/Not Applicable                Unknown/Not Applicable
# 4    Unknown/Not Applicable                Unknown/Not Applicable
# ..                      ...                                   ...
# 176           Chronic Phase                Unknown/Not Applicable
# 177  Unknown/Not Applicable                Unknown/Not Applicable
# 178  Unknown/Not Applicable  No Response (NR)/Stable Disease (SD)
# 179  Unknown/Not Applicable                Unknown/Not Applicable
# 180  Unknown/Not Applicable                Unknown/Not Applicable
#
#                               MDSResponse            JMMLResponse  \
# 0                  Unknown/Not Applicable  Unknown/Not Applicable
# 1                  Unknown/Not Applicable  Unknown/Not Applicable
# 2                  Unknown/Not Applicable  Unknown/Not Applicable
# 3    No Response (NR)/Stable Disease (SD)  Unknown/Not Applicable
# 4                  Unknown/Not Applicable  Unknown/Not Applicable
# ..                                    ...                     ...
# 176                Unknown/Not Applicable  Unknown/Not Applicable
# 177                Unknown/Not Applicable  Unknown/Not Applicable
# 178                Unknown/Not Applicable  Unknown/Not Applicable
# 179                Unknown/Not Applicable  Unknown/Not Applicable
# 180                Unknown/Not Applicable  Unknown/Not Applicable
#
#     MultipleMyelomaPCLResponse    CurrentDiseaseStatus
# 0       Unknown/Not Applicable  No Evidence of Disease
# 1       Unknown/Not Applicable          Active Disease
# 2       Unknown/Not Applicable          Active Disease
# 3       Unknown/Not Applicable          Active Disease
# 4       Unknown/Not Applicable          Active Disease
# ..                         ...                     ...
# 176     Unknown/Not Applicable          Active Disease
# 177     Unknown/Not Applicable  No Evidence of Disease
# 178     Unknown/Not Applicable          Active Disease
# 179     Unknown/Not Applicable          Active Disease
# 180     Unknown/Not Applicable  No Evidence of Disease
#
# [181 rows x 12 columns]
